# %% [markdown]
# # AMICI in pyPESTO
#
# **After this notebook you can...**
#
# * ...create a pyPESTO problem directly from an AMICI model or through PEtab.
# * ...perform parameter estimation of your amici model and adjust advanced settings for this.
# * ...evaluate an optimization through basic visualizations.
# * ...inspect parameter uncertainties through profile likelihoods and MCMC sampling.
#
# To run optimizations and/or uncertainty analysis, we turn to pyPESTO (**P**arameter **ES**timation **TO**olbox for python).
#
# pyPESTO is a Python tool for parameter estimation. It provides an interface to the model simulation tool [AMICI](https://github.com/AMICI-dev/AMICI) for the simulation of Ordinary Differential Equation (ODE) models specified in the SBML format. With it, we can optimize our model parameters given measurement data, we can do uncertainty analysis via profile likelihoods and/or through sampling methods. pyPESTO provides an interface to many optimizers, global and local, such as e.g. SciPy optimizers, Fides and Pyswarm. Additionally, it interfaces samplers such as pymc, emcee and some of its own samplers.

# %%
# import
import logging
import tempfile
from pprint import pprint

import amici
import matplotlib as mpl
import numpy as np
import petab
from IPython.display import Markdown, display

import pypesto.optimize as optimize
import pypesto.petab
import pypesto.profile as profile
import pypesto.sample as sample
import pypesto.store as store
import pypesto.visualize as visualize
import pypesto.visualize.model_fit as model_fit

mpl.rcParams["figure.dpi"] = 100
mpl.rcParams["font.size"] = 18

# Set seed for reproducibility
np.random.seed(1912)


# name of the model that will also be the name of the python module
model_name = "boehm_JProteomeRes2014"

# output directory
model_output_dir = "tmp/" + model_name

# %% [markdown]
# ## 1. Create a pyPESTO problem

# %% [markdown]
# ### Create a pyPESTO objective from AMICI
#
# Before we can use AMICI to simulate our model, the SBML model needs to be translated to C++ code. This is done by `amici.SbmlImporter`.

# %%
sbml_file = f"/PyPESTO/doc/example/{model_name}/{model_name}.xml"
# sbml_file = "/Users/devoncallan/Documents/GitHub/pyPESTO/doc/example/boehm_JProteomeRes2014/boehm_JProteomeRes2014.xml"
# sbml_file = "/PyPESTO/doc/example/boehm_JProteomeRes2014/boehm_JProteomeRes2014.xml"
# Create an SbmlImporter instance for our SBML model
sbml_importer = amici.SbmlImporter(sbml_file, show_sbml_warnings=False)

# %% [markdown]
# In this example, we want to specify fixed parameters, observables and a $\sigma$ parameter. Unfortunately, the latter two are not part of the [SBML standard](https://sbml.org/). However, they can be provided to `amici.SbmlImporter.sbml2amici` as demonstrated in the following.

# %% [markdown]
# #### Constant parameters
#
# Constant parameters, i.e., parameters with respect to which no sensitivities are to be computed (these are often parameters specifying a certain experimental condition) are provided as a list of parameter names.

# %%
constant_parameters = ["ratio", "specC17"]

# %% [markdown]
# #### Observables
#
# We used SBML's [`AssignmentRule`](https://sbml.org/software/libsbml/5.18.0/docs/formatted/python-api/classlibsbml_1_1_assignment_rule.html) as a non-standard way to specify *Model outputs* within the SBML file. These rules need to be removed prior to the model import (AMICI does at this time not support these rules). This can be easily done using `amici.assignmentRules2observables()`.
#
# In this example, we introduced parameters named `observable_*` as targets of the observable AssignmentRules. Where applicable we have `observable_*_sigma` parameters for $\sigma$ parameters (see below).

# %%
# Retrieve model output names and formulae from AssignmentRules and remove the respective rules
observables = amici.assignmentRules2observables(
    sbml_importer.sbml,  # the libsbml model object
    filter_function=lambda variable: variable.getId().startswith("observable_")
    and not variable.getId().endswith("_sigma"),
)
print("Observables:")
pprint(observables)
# Out:
# Observables:
# {'observable_pSTAT5A_rel': {'formula': '(100 * pApB + 200 * pApA * specC17) / '
#                                        '(pApB + STAT5A * specC17 + 2 * pApA * '
#                                        'specC17)',
#                             'name': 'observable_pSTAT5A_rel'},
#  'observable_pSTAT5B_rel': {'formula': '-(100 * pApB - 200 * pBpB * (specC17 - '
#                                        '1)) / (STAT5B * (specC17 - 1) - pApB + '
#                                        '2 * pBpB * (specC17 - 1))',
#                             'name': 'observable_pSTAT5B_rel'},
#  'observable_rSTAT5A_rel': {'formula': '(100 * pApB + 100 * STAT5A * specC17 + '
#                                        '200 * pApA * specC17) / (2 * pApB + '
#                                        'STAT5A * specC17 + 2 * pApA * specC17 '
#                                        '- STAT5B * (specC17 - 1) - 2 * pBpB * '
#                                        '(specC17 - 1))',
#                             'name': 'observable_rSTAT5A_rel'}}

# %% [markdown]
# #### $\sigma$ parameters
#
# To specify measurement noise as a parameter, we simply provide a dictionary with observable names as keys and a list of (preexisting) parameter names as values to indicate which sigma parameter is to be used for which observable.

# %%
sigma_vals = ["sd_pSTAT5A_rel", "sd_pSTAT5B_rel", "sd_rSTAT5A_rel"]
observable_names = observables.keys()
sigmas = dict(zip(list(observable_names), sigma_vals))
pprint(sigmas)
# Out:
# {'observable_pSTAT5A_rel': 'sd_pSTAT5A_rel',
#  'observable_pSTAT5B_rel': 'sd_pSTAT5B_rel',
#  'observable_rSTAT5A_rel': 'sd_rSTAT5A_rel'}

# %% [markdown]
# #### Generating the module
#
# Now we can generate the python module for our model. `amici.SbmlImporter.sbml2amici` will symbolically derive the sensitivity equations, generate C++ code for model simulation, and assemble the python module.

# %%
# %%time

sbml_importer.sbml2amici(
    model_name,
    model_output_dir,
    verbose=False,
    observables=observables,
    constant_parameters=constant_parameters,
    sigmas=sigmas,
)
# Out:
# CPU times: user 827 ms, sys: 28.7 ms, total: 855 ms
# Wall time: 12.4 s

# %% [markdown]
# #### Importing the module and loading the model
#
# If everything went well, we are ready to load the newly generated model:

# %%
model_module = amici.import_model_module(model_name, model_output_dir)

# %% [markdown]
# Afterwards, we can get an instance of our model from which we can retrieve information such as parameter names:

# %%
model = model_module.getModel()

print("Model parameters:", list(model.getParameterIds()))
print("Model outputs:   ", list(model.getObservableIds()))
print("Model states:    ", list(model.getStateIds()))
# Out:
# Model parameters: ['Epo_degradation_BaF3', 'k_exp_hetero', 'k_exp_homo', 'k_imp_hetero', 'k_imp_homo', 'k_phos', 'sd_pSTAT5A_rel', 'sd_pSTAT5B_rel', 'sd_rSTAT5A_rel']
# Model outputs:    ['observable_pSTAT5A_rel', 'observable_pSTAT5B_rel', 'observable_rSTAT5A_rel']
# Model states:     ['STAT5A', 'STAT5B', 'pApB', 'pApA', 'pBpB', 'nucpApA', 'nucpApB', 'nucpBpB']

# %% [markdown]
# #### Running simulations and analyzing results
#
# After importing the model, we can run simulations using `amici.runAmiciSimulation`. This requires a `Model` instance and a `Solver` instance. But, in order go gain a value of fit, we also need to provide some data.

# %%
# we prepare our data as it is reported in the benchmark collection

# timepoints
timepoints = np.array(
    [
        0.0,
        2.5,
        5.0,
        10.0,
        15.0,
        20.0,
        30.0,
        40.0,
        50.0,
        60.0,
        80.0,
        100.0,
        120.0,
        160.0,
        200.0,
        240.0,
    ]
)

# measurements
meas_pSTAT5A_rel = np.array(
    [
        7.901073,
        66.363494,
        81.171324,
        94.730308,
        95.116483,
        91.441717,
        91.257099,
        93.672298,
        88.754233,
        85.269703,
        81.132395,
        76.135928,
        65.248059,
        42.599659,
        25.157798,
        15.430182,
    ]
)
meas_pSTAT5B_rel = np.array(
    [
        4.596533,
        29.634546,
        46.043806,
        81.974734,
        80.571609,
        79.035720,
        75.672380,
        71.624720,
        69.062863,
        67.147384,
        60.899476,
        54.809258,
        43.981290,
        29.771458,
        20.089017,
        10.961845,
    ]
)
meas_rSTAT5A_rel = np.array(
    [
        14.723168,
        33.762342,
        36.799851,
        49.717602,
        46.928120,
        47.836575,
        46.928727,
        40.597753,
        43.783664,
        44.457388,
        41.327159,
        41.062733,
        39.235830,
        36.619461,
        34.893714,
        32.211077,
    ]
)

# %%
benchmark_parameters = np.array(
    [
        -1.568917588,
        -4.999704894,
        -2.209698782,
        -1.786006548,
        4.990114009,
        4.197735488,
        0.585755271,
        0.818982819,
        0.498684404,
    ]
)
# set timepoints for which we want to simulate the model
model.setTimepoints(timepoints)

# set fixed parameters for which we want to simulate the model
model.setFixedParameters(np.array([0.693, 0.107]))

# set parameters to optimal values found in the benchmark collection
model.setParameterScale(amici.ParameterScaling.log10)
model.setParameters(benchmark_parameters)

# Create solver instance
solver = model.getSolver()

# Run simulation using model parameters from the benchmark collection and default solver options
rdata = amici.runAmiciSimulation(model, solver)

# %%
rdata.x.shape
# Out:
# (16, 8)

# %%
# Create edata instance with dimensions and timepoints
edata = amici.ExpData(
    3,  # number of observables
    0,  # number of event outputs
    0,  # maximum number of events
    timepoints,  # timepoints
)
# set observed data
edata.setObservedData(meas_pSTAT5A_rel, 0)
edata.setObservedData(meas_pSTAT5B_rel, 1)
edata.setObservedData(meas_rSTAT5A_rel, 2)

# set standard deviations to optimal values found in the benchmark collection
edata.setObservedDataStdDev(np.array(16 * [10**0.585755271]), 0)
edata.setObservedDataStdDev(np.array(16 * [10**0.818982819]), 1)
edata.setObservedDataStdDev(np.array(16 * [10**0.498684404]), 2)

# %%
rdata.x
# Out:
# array([[1.43866800e+02, 6.37332000e+01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.34614825e+01, 2.88662931e+01, 1.73038445e+01, 5.38666370e-05,
#         1.57043347e-05, 1.12989532e+02, 1.44740517e+00, 2.65965677e+01],
#        [3.40645160e+01, 1.96396701e+01, 2.10101067e+01, 2.04430398e-05,
#         6.79530988e-06, 1.36155799e+02, 3.93060524e+00, 3.39422234e+01],
#        [2.17740042e+01, 1.28936813e+01, 2.26400301e+01, 7.29835794e-06,
#         2.55918945e-06, 1.49922972e+02, 9.56261504e+00, 3.90845556e+01],
#        [1.78289556e+01, 1.02603491e+01, 2.23703263e+01, 4.27571056e-06,
#         1.41605733e-06, 1.53605366e+02, 1.53104077e+01, 4.07264967e+01],
#        [1.63397287e+01, 8.95194827e+00, 2.15687544e+01, 3.13800944e-06,
#         9.41889135e-07, 1.54369341e+02, 2.09093965e+01, 4.12091836e+01],
#        [1.59598622e+01, 7.84978289e+00, 1.95400549e+01, 2.28580486e-06,
#         5.52963235e-07, 1.52878985e+02, 3.13834297e+01, 4.08424024e+01],
#        [1.68960378e+01, 7.57954898e+00, 1.74766766e+01, 1.95599172e-06,
#         3.93626262e-07, 1.49923889e+02, 4.08004766e+01, 3.97639430e+01],
#        [1.83667566e+01, 7.66955413e+00, 1.55593994e+01, 1.76473146e-06,
#         3.07718761e-07, 1.46418864e+02, 4.91998206e+01, 3.84066944e+01],
#        [2.01288219e+01, 7.95104757e+00, 1.38272768e+01, 1.61832903e-06,
#         2.52510161e-07, 1.42637834e+02, 5.66687252e+01, 3.69287765e+01],
#        [2.42069632e+01, 8.82343815e+00, 1.09015489e+01, 1.36440592e-06,
#         1.81275326e-07, 1.34584159e+02, 6.91907907e+01, 3.38618242e+01],
#        [2.88236874e+01, 9.92100118e+00, 8.58815427e+00, 1.12770348e-06,
#         1.33600125e-07, 1.26069390e+02, 7.90544169e+01, 3.08213049e+01],
#        [3.38427683e+01, 1.11365004e+01, 6.75632993e+00, 9.06275981e-07,
#         9.81355141e-08, 1.17230826e+02, 8.68156371e+01, 2.78994228e+01],
#        [4.45767625e+01, 1.36929095e+01, 4.13936155e+00, 5.34332377e-07,
#         5.04180371e-08, 9.91750057e+01, 9.76743105e+01, 2.25642896e+01],
#        [5.53512696e+01, 1.61684899e+01, 2.47997231e+00, 2.79972484e-07,
#         2.38890624e-08, 8.17101332e+01, 1.04245913e+02, 1.80088580e+01],
#        [6.52754787e+01, 1.83796875e+01, 1.44531755e+00, 1.32320167e-07,
#         1.04906443e-08, 6.59469775e+01, 1.08115833e+02, 1.42437198e+01]])

# %%
rdata = amici.runAmiciSimulation(model, solver, edata)

print("Chi2 value reported in benchmark collection: 47.9765479")
print(f"chi2 value using AMICI: {rdata['chi2']}")
# Out:
# Chi2 value reported in benchmark collection: 47.9765479
# chi2 value using AMICI: 47.97654199832919

# %% [markdown]
# #### Creating pyPESTO objective
#
# We are now set up to create our pyPESTO objective. This objective is a vital part of the pyPESTO infrastructure as it provides a blackbox interface to call any predefined objective function with some parameters and evaluate it. We can easily create an AmiciObjective by supplying the model, an amici solver and the data.
#
# Keep in mind, however, that you can use ANY function you would like for this.

# %%
# we make some more adjustments to our model and the solver
model.requireSensitivitiesForAllParameters()

solver.setSensitivityMethod(amici.SensitivityMethod.forward)
solver.setSensitivityOrder(amici.SensitivityOrder.first)


objective = pypesto.AmiciObjective(
    amici_model=model, amici_solver=solver, edatas=[edata], max_sensi_order=1
)

# %% [markdown]
# We can now call the objective function directly for any parameter. The value that is put out is the likelihood function. If we want to interact more with the AMICI returns, we can also return this by call and e.g., retrieve the chi2 value.

# %%
# the generic objective call
print(f"Objective value: {objective(benchmark_parameters)}")
# a call returning the AMICI data as well
obj_call_with_dict = objective(benchmark_parameters, return_dict=True)
print(
    f'Chi^2 value of the same parameters: {obj_call_with_dict["rdatas"][0]["chi2"]}'
)
# Out:
# Objective value: 138.22199675865204
# Chi^2 value of the same parameters: 47.97654199832919

# %% [markdown]
# Now this makes the whole process already somewhat easier, but still, getting here took us quite some coding and effort. This will only get more complicated, the more complex the model is. Therefore, in the next part, we will show you how to bypass the tedious lines of code by using PEtab.

# %% [markdown]
# ### Create a pyPESTO problem + objective from Petab

# %% [markdown]
# #### Background on PEtab
#
# <img src="https://github.com/PEtab-dev/PEtab/blob/main/doc/gfx/petab_files.png?raw=true" width="80%" alt="pyPESTO logo"/>
#
# pyPESTO supports the [PEtab](https://github.com/PEtab-dev/PEtab) standard. PEtab is a data format for specifying parameter estimation problems in systems biology.
#
# A PEtab problem consist of an [SBML](https://sbml.org) file, defining the model topology and a set of `.tsv` files, defining experimental conditions, observables, measurements and parameters (and their optimization bounds, scale, priors...). All files that make up a PEtab problem can be structured in a `.yaml` file. The `pypesto.Objective` coming from a PEtab problem corresponds to the negative-log-likelihood/negative-log-posterior distribution of the parameters.
#
# For more details on PEtab, the interested reader is referred to [PEtab's format definition](https://petab.readthedocs.io/en/latest/documentation_data_format.html), for examples the reader is referred to the [PEtab benchmark collection](https://github.com/Benchmarking-Initiative/Benchmark-Models-PEtab). The Model from _[Böhm et al. JProteomRes 2014](https://pubs.acs.org/doi/abs/10.1021/pr5006923)_ is part of the benchmark collection and will be used as the running example throughout this notebook.

# %%
# %%capture
petab_yaml = f"/PyPESTO/doc/example/{model_name}/{model_name}.yaml"
# petab_yaml = f"/PyPESTO/{model_name}/{model_name}.yaml"

petab_problem = petab.Problem.from_yaml(petab_yaml)
importer = pypesto.petab.PetabImporter(petab_problem)
problem = importer.create_problem(verbose=False)
# Out:
# Compiling amici model to folder /PyPESTO/amici_models/0.26.1/FullModel.

# %%
# Check the dataframes. First the parameter dataframe
petab_problem.parameter_df.head()
# Out:
#                                parameterName parameterScale  lowerBound  \
# parameterId
# Epo_degradation_BaF3  EPO_{degradation,BaF3}          log10     0.00001
# k_exp_hetero                  k_{exp,hetero}          log10     0.00001
# k_exp_homo                      k_{exp,homo}          log10     0.00001
# k_imp_hetero                  k_{imp,hetero}          log10     0.00001
# k_imp_homo                      k_{imp,homo}          log10     0.00001
#
#                       upperBound  nominalValue  estimate
# parameterId
# Epo_degradation_BaF3      100000      0.026983         1
# k_exp_hetero              100000      0.000010         1
# k_exp_homo                100000      0.006170         1
# k_imp_hetero              100000      0.016368         1
# k_imp_homo                100000  97749.379402         1

# %%
# Check the observable dataframe
petab_problem.observable_df.head()
# Out:
#               observableName  \
# observableId
# pSTAT5A_rel              NaN
# pSTAT5B_rel              NaN
# rSTAT5A_rel              NaN
#
#                                               observableFormula  \
# observableId
# pSTAT5A_rel   (100 * pApB + 200 * pApA * specC17) / (pApB + ...
# pSTAT5B_rel   -(100 * pApB - 200 * pBpB * (specC17 - 1)) / (...
# rSTAT5A_rel   (100 * pApB + 100 * STAT5A * specC17 + 200 * p...
#
#                              noiseFormula observableTransformation  \
# observableId
# pSTAT5A_rel   noiseParameter1_pSTAT5A_rel                      lin
# pSTAT5B_rel   noiseParameter1_pSTAT5B_rel                      lin
# rSTAT5A_rel   noiseParameter1_rSTAT5A_rel                      lin
#
#              noiseDistribution
# observableId
# pSTAT5A_rel             normal
# pSTAT5B_rel             normal
# rSTAT5A_rel             normal

# %%
# Check the measurement dataframe
petab_problem.measurement_df.head()
# Out:
#   observableId  preequilibrationConditionId simulationConditionId  \
# 0  pSTAT5A_rel                          NaN          model1_data1
# 1  pSTAT5A_rel                          NaN          model1_data1
# 2  pSTAT5A_rel                          NaN          model1_data1
# 3  pSTAT5A_rel                          NaN          model1_data1
# 4  pSTAT5A_rel                          NaN          model1_data1
#
#    measurement  time  observableParameters noiseParameters  \
# 0     7.901073   0.0                   NaN  sd_pSTAT5A_rel
# 1    66.363494   2.5                   NaN  sd_pSTAT5A_rel
# 2    81.171324   5.0                   NaN  sd_pSTAT5A_rel
# 3    94.730308  10.0                   NaN  sd_pSTAT5A_rel
# 4    95.116483  15.0                   NaN  sd_pSTAT5A_rel
#
#                   datasetId
# 0  model1_data1_pSTAT5A_rel
# 1  model1_data1_pSTAT5A_rel
# 2  model1_data1_pSTAT5A_rel
# 3  model1_data1_pSTAT5A_rel
# 4  model1_data1_pSTAT5A_rel

# %%
# check the condition dataframe
petab_problem.condition_df.head()
# Out:
#              conditionName
# conditionId
# model1_data1    condition1

# %% [markdown]
# This was really straightforward. With this, we are still able to do all the same things we did before and also adjust solver setting, change the model, etc.

# %%
# call the objective function
print(f"Objective value: {problem.objective(benchmark_parameters)}")
# change things in the model
problem.objective.amici_model.requireSensitivitiesForAllParameters()
# change solver settings
print(
    f"Absolute tolerance before change: {problem.objective.amici_solver.getAbsoluteTolerance()}"
)
problem.objective.amici_solver.setAbsoluteTolerance(1e-15)
print(
    f"Absolute tolerance after change: {problem.objective.amici_solver.getAbsoluteTolerance()}"
)
# Out:
# Objective value: 138.22199677125144
# Absolute tolerance before change: 1e-16
# Absolute tolerance after change: 1e-15

# %% [markdown]
# Now we are good to go and start the first optimization.

# %% [markdown]
# ## 2. Optimization
#
# Once setup, the optimization can be done very quickly with default settings. If needed, these settings can be highly individualized and change according to the needs of our model. In this section, we shall go over some of these settings.

# %% [markdown]
# ### Optimizer
#
# The optimizer determines the algorithm with which we optimize our model. The main disjunction is between global and local optimizers.
#
# pyPESTO provides an interface to many optimizers, such as Fides, ScipyOptimizers, Pyswarm and many more. For a whole list of supported optimizers with settings for each optimizer you can [have a look here](https://pypesto.readthedocs.io/en/latest/api.html#optimize).

# %%
optimizer_options = {"maxiter": 1e4, "fatol": 1e-12, "frtol": 1e-12}

optimizer = optimize.FidesOptimizer(
    options=optimizer_options, verbose=logging.WARN
)

# %% [markdown]
# ### Startpoint method
#
# The startpoint method describes how you want to choose your startpoints, in case you do a multistart optimization. The default here is `uniform` meaning that each startpoint is a uniform sample from the allowed parameter space. The other two notable options are either `latin_hypercube` or a self defined function.

# %%
startpoint_method = pypesto.startpoint.uniform

# %% [markdown]
# ### History options
#
# In some cases, it is good to trace what the optimizer did in each step, i.e., the history. There is a multitude of options on what to report here, but the most important one is `trace_record` which turns the history function on and off.

# %%
# save optimizer trace
history_options = pypesto.HistoryOptions(trace_record=True)

# %% [markdown]
# ### Optimization options
#
# Some further possible options for the optimization. Notably `allow_failed_starts`, which in case of a very complicated objective function, can help get to the desired number of optimizations when turned off. As we do not need this here, we create the default options.

# %%
opt_options = optimize.OptimizeOptions()
opt_options
# Out:
# {'allow_failed_starts': True,
#  'report_sres': True,
#  'report_hess': True,
#  'history_beats_optimizer': True}

# %% [markdown]
# ### Running the optimization
#
# We now only need to decide on the number of starts as well as the engine we want to use for the optimization.

# %%
n_starts = 20  # usually a value >= 100 should be used
engine = pypesto.engine.MultiProcessEngine()
# Out:
# Engine will use up to 8 processes (= CPU count).

# %%
# %%time
result = optimize.minimize(
    problem=problem,
    optimizer=optimizer,
    n_starts=n_starts,
    startpoint_method=startpoint_method,
    engine=engine,
    options=opt_options,
)
# Out:
# <timed exec>:1: DeprecationWarning: Passing `startpoint_method` directly is deprecated, use `problem.startpoint_method` instead.
#   0%|                                                    | 0/20 [00:00<?, ?it/s]2024-08-14 06:23:57.983 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 142.61 and h = 2.32624e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.003 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 142.61: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.001 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.417 and h = 3.70059e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.031 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.417: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.075 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.431 and h = 3.4136e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.108 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.431: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.193 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 146.027 and h = 4.68576e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.213 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 146.027: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.233 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 87.4803 and h = 1.63729e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.252 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 87.4803: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.447 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.452 and h = 3.06749e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.466 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.452: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58.739 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 88.7463 and h = 1.21243e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:58.747 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 88.7463: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:58 fides(WARNING) Stopping as trust region radius 2.22E-16 is smaller than machine precision.
# 2024-08-14 06:23:58 fides(WARNING) Stopping as trust region radius 1.11E-16 is smaller than machine precision.
# 2024-08-14 06:23:59 fides(WARNING) Stopping as trust region radius 1.34E-16 is smaller than machine precision.
#   5%|██▏                                         | 1/20 [00:01<00:33,  1.79s/it]2024-08-14 06:23:59 fides(WARNING) Stopping as trust region radius 1.07E-16 is smaller than machine precision.
# 2024-08-14 06:23:59.282 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.628 and h = 3.64491e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.301 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.628: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.353 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 158.824 and h = 1.91345e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.355 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 158.824: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.406 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 74.3074 and h = 4.63321e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.419 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 74.3074: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59 fides(WARNING) Stopping as trust region radius 1.03E-16 is smaller than machine precision.
#  15%|██████▌                                     | 3/20 [00:02<00:10,  1.67it/s]2024-08-14 06:23:59 fides(WARNING) Stopping as trust region radius 1.23E-16 is smaller than machine precision.
# 2024-08-14 06:23:59.612 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 84.0142 and h = 1.59582e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.613 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 84.0142: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59 fides(WARNING) Stopping as trust region radius 6.67E-17 is smaller than machine precision.
# 2024-08-14 06:23:59.675 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 84.1259 and h = 1.74777e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.676 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 84.1259: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.728 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 144.071 and h = 3.52281e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.730 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 144.071: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.782 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 107.336 and h = 1.32029e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.788 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 107.336: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.930 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 90.7916 and h = 2.40882e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.931 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 90.7916: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.942 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 91.192 and h = 2.65932e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.943 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 91.192: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.974 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 88.9805 and h = 2.30757e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.975 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 88.9805: AMICI failed to integrate the forward problem
# 2024-08-14 06:23:59.976 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.991 and h = 2.30253e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:23:59.980 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.991: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:00.013 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 90.6209 and h = 3.05087e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:00.017 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 90.6209: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:00.070 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 147.565 and h = 3.84406e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:00.079 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 147.565: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 6.28E-17 is smaller than machine precision.
# 2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 8.96E-17 is smaller than machine precision.
#  30%|█████████████▏                              | 6/20 [00:02<00:05,  2.55it/s]2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 1.26E-16 is smaller than machine precision.
# 2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 6.18E-17 is smaller than machine precision.
# 2024-08-14 06:24:00.409 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 145.686 and h = 4.02726e-05, the error test failed repeatedly or with |h| = hmin.
#  55%|███████████████████████▋                   | 11/20 [00:03<00:01,  5.58it/s]2024-08-14 06:24:00.413 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 145.686: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:00.559 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 89.1879 and h = 1.37845e-05, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:00.560 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 89.1879: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 1.82E-16 is smaller than machine precision.
#  65%|███████████████████████████▉               | 13/20 [00:03<00:01,  6.43it/s]2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 1.13E-16 is smaller than machine precision.
# 2024-08-14 06:24:00 fides(WARNING) Stopping as trust region radius 1.18E-16 is smaller than machine precision.
#  75%|████████████████████████████████▎          | 15/20 [00:03<00:00,  6.62it/s]2024-08-14 06:24:01 fides(WARNING) Stopping as trust region radius 1.06E-16 is smaller than machine precision.
# 2024-08-14 06:24:01 fides(WARNING) Stopping as trust region radius 6.23E-17 is smaller than machine precision.
# 2024-08-14 06:24:01 fides(WARNING) Stopping as trust region radius 2.13E-16 is smaller than machine precision.
# 2024-08-14 06:24:01.665 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 132.026 and h = 7.75768e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:01.666 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 132.026: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:01.876 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 105.444 and h = 7.99862e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:01.878 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 105.444: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02.077 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 112.501 and h = 8.34344e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.079 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 112.501: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02.315 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 108.653 and h = 8.26446e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.316 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 108.653: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02.397 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 161.972 and h = 9.49186e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.398 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 161.972: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02.520 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 154.399 and h = 9.00972e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.521 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 154.399: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02.536 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 141.441 and h = 8.52354e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.537 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 141.441: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02 fides(WARNING) Stopping as trust region radius 1.83E-16 is smaller than machine precision.
# 2024-08-14 06:24:02.789 - amici.swig_wrappers - DEBUG - [model1_data1][CVODES:CVode:ERR_FAILURE] AMICI ERROR: in module CVODES in function CVode : At t = 168.711 and h = 5.04884e-06, the error test failed repeatedly or with |h| = hmin.
# 2024-08-14 06:24:02.790 - amici.swig_wrappers - ERROR - [model1_data1][FORWARD_FAILURE] AMICI forward simulation failed at t = 168.711: AMICI failed to integrate the forward problem
# 2024-08-14 06:24:02 fides(WARNING) Stopping as trust region radius 5.85E-17 is smaller than machine precision.
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.55it/s]
# CPU times: user 186 ms, sys: 154 ms, total: 340 ms
# Wall time: 5.91 s

# %% [markdown]
# Now as a first step after the optimization, we can take a look at the summary of the optimizer:

# %%
display(Markdown(result.summary()))
# Out:
# ## Optimization Result
#
# * number of starts: 20
# * best value: 145.7594342253718, id=17
# * worst value: 249.74599566317852, id=3
# * number of non-finite values: 0
#
# * execution time summary:
# 	* Mean execution time: 1.590s
# 	* Maximum execution time: 3.243s,	id=15
# 	* Minimum execution time: 0.899s,	id=3
# * summary of optimizer messages:
#
#   |   Count | Message                                  |
#   |--------:|:-----------------------------------------|
#   |      19 | Trust Region Radius too small to proceed |
#   |       1 | Converged according to fval difference   |
#
# * best value found (approximately) 1 time(s)
# * number of plateaus found: 3
#
# A summary of the best run:
#
# ### Optimizer Result
#
# * optimizer used: <FidesOptimizer  hessian_update=default verbose=30 options={'maxiter': 10000.0, 'fatol': 1e-12, 'frtol': 1e-12}>
# * message: Trust Region Radius too small to proceed
# * number of evaluations: 146
# * time taken to optimize: 1.007s
# * startpoint: [-2.59120601  0.69656874 -3.88289712 -1.74846428 -1.58175173  3.39830011
#   0.0917892  -0.85030875 -3.77417568]
# * endpoint: [-1.52342474 -4.99907998 -2.03439993 -1.83082656 -1.6738871   3.94118586
#   0.50778976  0.80381151  0.79609388]
# * final objective value: 145.7594342253718
# * final gradient value: [ 9.47312173e-04  2.80940945e-02  2.59768657e-03  3.25903549e-03
#   9.16010489e-04 -8.80897669e-03 -2.73351267e-04  1.65804114e-04
#  -1.07709538e-05]
# * final hessian value: [[ 2.37369167e+03  3.59743421e-01  2.64694975e+02  2.61593242e+03
#    8.75343853e+02 -8.64967188e+02  6.90862905e+01 -4.51777813e+01
#   -2.39106904e+01]
#  [ 3.59743421e-01  2.96260220e-04  2.94319180e-02  3.65418797e-01
#    1.60791774e-01 -1.70828891e-01 -1.74766049e-04 -2.71018990e-02
#   -3.74123783e-02]
#  [ 2.64694975e+02  2.94319180e-02  7.03274523e+01  2.78200125e+02
#    1.49631505e+02 -1.35653628e+02 -3.39587164e+00 -3.45384074e-01
#    3.73527432e+00]
#  [ 2.61593242e+03  3.65418797e-01  2.78200125e+02  2.91425721e+03
#    9.22045670e+02 -8.64626788e+02  8.16217842e+01 -4.77312293e+01
#   -3.38980591e+01]
#  [ 8.75343853e+02  1.60791774e-01  1.49631505e+02  9.22045670e+02
#    4.25511776e+02 -4.03097700e+02  9.19534048e+00 -1.99742370e+01
#    1.07767873e+01]
#  [-8.64967188e+02 -1.70828891e-01 -1.35653628e+02 -8.64626788e+02
#   -4.03097700e+02  1.14624168e+03 -2.12490163e+01 -1.23824427e+01
#    3.36517424e+01]
#  [ 6.90862905e+01 -1.74766049e-04 -3.39587164e+00  8.16217842e+01
#    9.19534048e+00 -2.12490163e+01  8.48309992e+01  0.00000000e+00
#    0.00000000e+00]
#  [-4.51777813e+01 -2.71018990e-02 -3.45384074e-01 -4.77312293e+01
#   -1.99742370e+01 -1.23824427e+01  0.00000000e+00  8.48299880e+01
#    0.00000000e+00]
#  [-2.39106904e+01 -3.74123783e-02  3.73527432e+00 -3.38980591e+01
#    1.07767873e+01  3.36517424e+01  0.00000000e+00  0.00000000e+00
#    8.48303946e+01]]

# %% [markdown]
# We can see some informative statistics, such as the mean execution time, best and worst values, a small table on the exit messages of the optimizer as well as detailed info on the best optimizer.
#
# As our best start is just as good as the reported benchmark value, we shall now further inspect the result thorough some useful visualisations.

# %% [markdown]
# ## 3. Optimization visualization

# %% [markdown]
# ### Model fit
#
# Probably the most useful visualization there is, is one, where we visualize the found parameter dynamics against the measurements. This way we can see whether the fit is qualitatively and/or quantitatively good.

# %%
ax = model_fit.visualize_optimized_model_fit(
    petab_problem=petab_problem, result=result, pypesto_problem=problem
)

# %% [markdown]
# ### Waterfall plot
#
# The waterfall plot is a visualization of the final objective function values of each start. They are sorted from small to high and then plotted. Similar values will get clustered and get the same color.
#
# This helps to determine whether the result is reproducible and whether we reliably found a local minimum that we hope to be the global one.

# %%
visualize.waterfall(result);

# %% [markdown]
# ### Parameter plots
#
# To visualize the parameters, there is a multitude of options:

# %% [markdown]
# #### Parameter overview
#
# Here we plot the parameters of all starts within their bounds. This can tell us whether some bounds are always hit and might need to be questioned and if the best starts are similar or differ amongst themselves, hinting already for some non-identifiabilities.

# %%
visualize.parameters(result);

# %% [markdown]
# #### Parameter correlation plot
#
# To further look into possible uncertainties, we can plot the correlation of the final points. Sometimes, pairs of parameters are dependent on each other and fixing one might solve some non-identifiability.

# %%
visualize.parameters_correlation_matrix(result);

# %% [markdown]
# #### Parameter histogram + scatter
#
# In case we found some dependencies and for further investigation, we can also specifically look at the histograms of certain parameters and the pairwise parameter scatter plot.

# %%
visualize.parameter_hist(result=result, parameter_name="k_exp_hetero")
visualize.parameter_hist(result=result, parameter_name="k_imp_homo");

# %%
visualize.optimization_scatter(result, parameter_indices=[1, 4]);

# %% [markdown]
# We definitely need to look further into it, and thus we turn to uncertainty quantification in the next section.

# %% [markdown]
# ## 4. Uncertainty quantification
#
# This mainly consists of two parts:
# * Profile Likelihoods
# * MCMC sampling

# %% [markdown]
# ### Profile likelihood
#
# The profile likelihood uses an optimization scheme to calculate the confidence intervals for each parameter. We start with the best found parameter set of the optimization. Then in each step, we increase/decrease the parameter of interest, fix it and then run one local optimization. We do this until we either hit the bounds or reach a sufficiently bad fit.
#
# To run the profiling, we do not need a lot of setup, as we did this already for the optimization.

# %%
# %%time

result = profile.parameter_profile(
    problem=problem,
    result=result,
    optimizer=optimizer,
    engine=engine,
    profile_index=[0, 1],
)
# Out:
#   0%|                                                     | 0/2 [00:00<?, ?it/s]2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 1.28E-16 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 7.73E-17 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 6.54E-17 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 1.13E-16 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 6.04E-17 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 8.11E-17 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 1.13E-16 is smaller than machine precision.
# 2024-08-14 06:24:05 fides(WARNING) Stopping as trust region radius 1.11E-16 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 6.89E-17 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 1.16E-16 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 2.22E-16 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 1.29E-16 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 9.94E-17 is smaller than machine precision.
# 2024-08-14 06:24:06 fides(WARNING) Stopping as trust region radius 1.00E-16 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 5.95E-17 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 8.03E-17 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 1.08E-16 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 5.87E-17 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 9.63E-17 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 6.94E-17 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 1.54E-16 is smaller than machine precision.
# 2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 9.87E-17 is smaller than machine precision.
#  50%|██████████████████████▌                      | 1/2 [00:03<00:03,  3.08s/it]2024-08-14 06:24:07 fides(WARNING) Stopping as trust region radius 2.16E-16 is smaller than machine precision.
# 2024-08-14 06:24:08 fides(WARNING) Stopping as trust region radius 7.07E-17 is smaller than machine precision.
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.74s/it]
# CPU times: user 21.1 ms, sys: 22.9 ms, total: 44 ms
# Wall time: 3.51 s

# %% [markdown]
# We can visualize the profiles directly

# %%
# plot profiles
pypesto.visualize.profiles(result);

# %% [markdown]
# ### Sampling
#
# We can use MCMC sampling to get a distribution on the posterior of the parameters. Here again, we do not need a lot of setup. We only need to define a sampler, of which pyPESTO offers a multitude.

# %%
# Sampling
sampler = sample.AdaptiveMetropolisSampler()
result = sample.sample(
    problem=problem,
    sampler=sampler,
    n_samples=5000,
    result=result,
)
# Out:
# 100%|█████████████████████████████████████| 5000/5000 [00:02<00:00, 1937.40it/s]
# Elapsed time: 2.5871206960000013

# %% [markdown]
# For visualization purposes, we can visualize the trace of the objective function value, as well as a scatter plot of the parameters, just like in the optimization. We do omit the scatter plot here, as it has a very large size.

# %%
# plot objective function trace
visualize.sampling_fval_traces(result);
# Out:
# /PyPESTO/pypesto/visualize/sampling.py:79: UserWarning: Burn in index not found in the results, the full chain will be shown.
# You may want to use, e.g., `pypesto.sample.geweke_test`.
#   _, params_fval, _, _, _ = get_data_to_plot(

# %%
visualize.sampling_1d_marginals(result);
# Out:
# /PyPESTO/pypesto/visualize/sampling.py:1293: UserWarning: Burn in index not found in the results, the full chain will be shown.
# You may want to use, e.g., `pypesto.sample.geweke_test`.
#   nr_params, params_fval, theta_lb, theta_ub, param_names = get_data_to_plot(

# %% [markdown]
# ## 5. Saving results
#
# Lastly, the whole process took quite some time, but is not necessarily finished. It is therefore very useful, to be able to save the result as is. pyPESTO uses the HDF5 format, and with two very short commands we are able to read and write a result from and to an HDF5 file.

# %% [markdown]
# ### Save result object in HDF5 File

# %%
# create temporary file
fn = tempfile.NamedTemporaryFile(suffix=".hdf5", delete=False)
# write result with write_result function.
# Choose which parts of the result object to save with
# corresponding booleans.
store.write_result(
    result=result,
    filename=fn.name,
    problem=True,
    optimize=True,
    sample=True,
    profile=True,
)

# %% [markdown]
# ### Reload results

# %%
# Read result
result2 = store.read_result(fn, problem=True)

# close file
fn.close()

# %% [markdown]
# As the warning already suggests, we need to assign the problem again correctly.

# %%
result2.problem = problem

# %% [markdown]
# Now we are able to quickly load the results and visualize them.

# %% [markdown]
# ### Plot (reloaded) results

# %%
# plot profiles
pypesto.visualize.profiles(result2);
